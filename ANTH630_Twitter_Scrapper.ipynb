# %% [markdown]
# <a href="https://colab.research.google.com/github/evanhatt/ANTH630/blob/main/ANTH630_Twitter_Scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install snscrape
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 KB 4.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Pulling and Example Tweet

# %%
scraper = sntwitter.TwitterSearchScraper("#saami")

# %%
for tweet in scraper.get_items(): 
  break

# %%
hashtags = ["#saamirights", "#indigenouslandthreats", "#saamilandrights"]
n_tweets = 1_000

tweets = []
for hashtag in hashtags:
    scraper = sntwitter.TwitterSearchScraper(hashtag)
    for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
        data = [
            tweet.date,
            tweet.id,
            tweet.rawContent,
            tweet.user.username,
            tweet.likeCount,
            tweet.retweetCount,
        ]
        tweets.append(data)
        if i >= n_tweets:
            break
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
scraper = sntwitter.TwitterSearchScraper("#saami")

tweets =[]
n_tweets = 5_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('saami-tweets.csv', index=False)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# <ipython-input-4-b411f3bee356>:9: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.content,

# %%
scraper = sntwitter.TwitterSearchScraper("#landback")

tweets =[]
n_tweets = 5_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('saamilandrights-tweets.csv', index=False)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# <ipython-input-5-a2ace553fabf>:9: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.content,

# %%
scraper = sntwitter.TwitterSearchScraper("#sápmi")

tweets =[]
n_tweets = 5_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('sápmi-tweets.csv', index=False)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# <ipython-input-6-fa16b79067d3>:9: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.content,

# %%
scraper = sntwitter.TwitterSearchScraper("#IndigenousPeoples")

tweets =[]
n_tweets = 5_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('IndigenousPeoples-tweets.csv', index=False)
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# <ipython-input-7-f0d4aea3e783>:9: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.content,

# %%
scraper = sntwitter.TwitterSearchScraper("#WindFarms")

tweets =[]
n_tweets = 1_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('WindFarms-tweets.csv', index=False)

# %%
scraper = sntwitter.TwitterSearchScraper("#Fosen")

tweets =[]
n_tweets = 5_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('Fosen-tweets.csv', index=False)

# %%
scraper = sntwitter.TwitterSearchScraper("#Sami")

tweets =[]
n_tweets = 5_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('Sami-tweets.csv', index=False)

# %%
scraper = sntwitter.TwitterSearchScraper("#Fosendommen")

tweets =[]
n_tweets = 311 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.rawContent, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i >= n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('Fosendommen-tweets.csv', index=False)

# %%
scraper = sntwitter.TwitterSearchScraper("#StandWithSápmi")

tweets =[]
n_tweets = 1_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('StandWithSápmi-tweets.csv', index=False)

# %%
scraper = sntwitter.TwitterSearchScraper("#SamiRights")

tweets =[]
n_tweets = 1_000 
for i, tweet in tqdm(enumerate(scraper.get_items()), total=n_tweets):
  data = [
      tweet.date,
      tweet.id, 
      tweet.content, 
      tweet.user.username, 
      tweet.likeCount, 
      tweet.retweetCount,
  ] 
  tweets.append(data)
  if i > n_tweets: 
    break

tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"])

tweet_df.to_csv('SamiRights-tweets.csv', index=False)

# %%
len(tweets)
# Out:
# 105

# %%
tweet_df = pd.DataFrame(tweets, columns= ["date", "id", "content", "username", "like_count", "retweet_count"]
             )

# %%
tweet_df.head(20)
# Out:
#                         date                   id  \
# 0  2023-03-01 21:32:08+00:00  1631044676508590082
# 1  2023-03-01 16:30:02+00:00  1630968646888562688
# 2  2023-03-01 14:20:12+00:00  1630935977140125696
# 3  2023-02-28 08:37:02+00:00  1630487227133472769
# 4  2023-02-28 01:00:02+00:00  1630372219711897602
# 5  2023-02-27 21:01:13+00:00  1630312118535815172
# 6  2023-02-27 21:00:12+00:00  1630311863878664194
# 7  2023-02-27 20:30:03+00:00  1630304273337659395
# 8  2023-02-27 17:36:34+00:00  1630260615485837315
# 9  2023-02-27 11:14:55+00:00  1630164570625957891
# 10 2023-02-26 23:09:08+00:00  1629981920447561728
# 11 2023-02-26 19:00:02+00:00  1629919235748003840
# 12 2023-02-24 21:00:01+00:00  1629224654630944775
# 13 2023-02-22 18:31:05+00:00  1628462396317569025
# 14 2023-02-22 09:30:02+00:00  1628326237339893760
# 15 2023-02-18 14:00:00+00:00  1626944624807010306
# 16 2023-02-18 13:00:02+00:00  1626929535722852353
# 17 2023-02-17 22:05:34+00:00  1626704432271601665
# ...

# %%
tweet_df.to_csv('pthon-tweets.csv', index=False)

# %% [markdown]
# Progress Bar for Status on Tweet Scraping
